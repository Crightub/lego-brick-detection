# %%
from google.colab import drive
import os
drive.mount('/content/drive', force_remount=True)

BASE_PATH = "/content/drive/MyDrive/Brick_Detection/"

REPO_DIR = os.path.join(BASE_PATH, "repo")

if not os.path.exists(REPO_DIR):
    print("Cloning repository...")
    # !git clone https://github.com/Crightub/lego-brick-detection.git {REPO_DIR}
else:
    print("Repo already exists, pulling latest changes...")
    # !git -C {REPO_DIR} pull

os.chdir(REPO_DIR)
print("Working directory:", os.getcwd())

# 3. Install dependencies
print("Installing requirements...")
# !pip install -r requirements.txt -q

print("Copying data to local storage...")
# !cp -r {BASE_PATH}/data /content/data
print("Done!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       2 import os
#       3 drive.mount('/content/drive', force_remount=True)
#
# ModuleNotFoundError: No module named 'google'

# %%
import argparse

colab_train_preset = argparse.Namespace(
    data_yaml='content/YoloStage1/local_dataset.yaml',
    lr=1e-4,
    weight_decay=1e-4,
    batch_size=8,
    epochs=10,
    device='0',
    model_out_dir=os.path.join(BASE_PATH, 'model/stage1'),
    resume=False,
)

# %%
from YoloStage1.train_stage1 import main

main(colab_train_preset)
