# %%
from train import main

import argparse

colab_train_preset = argparse.Namespace(
    train_size=15,
    val_size=5,
    lr=1e-4,
    weight_decay=1e-4,
    batch_size=5,
    epochs=1,
    milestones=[100, 150],
    gamma=0.1,
    device='cpu',
    model_out_dir='model'
)

# %%
main(colab_train_preset)
# Out:
# Using device: cpu
# Loading data...
# Number of classes: 201
# Create DataLoader...
# Loading Model...
# Setup Training...
# Epoch: 0
# Epoch [0] Batch [0]
#   - loss_classifier: 5.0744
#   - loss_box_reg: 0.6316
#   - loss_objectness: 5.3434
#   - loss_rpn_box_reg: 0.3446
# Epoch [0] Batch [1]
#   - loss_classifier: 4.4132
#   - loss_box_reg: 0.4457
#   - loss_objectness: 0.2272
#   - loss_rpn_box_reg: 0.4544
# Epoch [0] Batch [2]
#   - loss_classifier: 3.0559
#   - loss_box_reg: 0.5148
#   - loss_objectness: 0.1723
#   - loss_rpn_box_reg: 0.4225
# Evaluator Time: 0.0015003681182861328
#
# ...
#     Lego Part Performance (IoU=0.5)
# ...
# Label/Name                | AP
# ----------------------------------------
# ID 188                    |    0.26%
# ID 76                     |    0.02%
# ID 58                     |    0.02%
# ID 1                      |    0.00%
# ID 2                      |    0.00%
# ID 3                      |    0.00%
# ID 4                      |    0.00%
# ...
